# %% [markdown]
# #### Clarivate

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

headers = {'Cookie':'_gcl_au=1.1.87219360.1694744764; _gd_visitor=bd7df774-e30b-4965-8ba0-2f5ea57634ae; _gd_session=ff3323a9-a294-45a6-866b-d391ad1d1f78; ELOQUA=GUID=C09F684110194940AE5CCABB70BD9FF9; _gd_svisitor=4c8ec817dd173700fdbf59647202000054c20000; OptanonAlertBoxClosed=2023-09-15T02:26:09.503Z; _biz_sid=4d4db8; ln_or=eyIzODM1NTQiOiJkIn0%3D; _gid=GA1.2.579947261.1694744770; _vwo_uuid_v2=D1337E96E280F4E422A74EC96EB983938|3487a0ec593c1602f5062b8a9fa4f55a; _biz_uid=197a026762244588aeb3e79d3511ff64; _biz_flagsA=%7B%22Version%22%3A1%2C%22ViewThrough%22%3A%221%22%2C%22XDomain%22%3A%221%22%7D; _vis_opt_s=1%7C; _vis_opt_test_cookie=1; _vwo_uuid=D1337E96E280F4E422A74EC96EB983938; utm_source=www-google-com; utm_medium=Organic/Search; _vwo_ds=3%3Aa_0%2Ct_0%3A0%241694744770%3A68.26476793%3A%3A49_0%2C48_0%2C44_0%2C43_0%2C31_0%2C30_0%2C27_0%2C26_0%2C25_0%2C24_0%3A176_0%2C137_0%2C134_0%2C74_0%2C3_0%2C2_0%3A1; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Sep+15+2023+10%3A31%3A16+GMT%2B0800+(%E4%B8%AD%E5%9B%BD%E6%A0%87%E5%87%86%E6%97%B6%E9%97%B4)&version=202307.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=e53a7d6c-180f-4d6d-9143-65b4cdb3c658&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A1%2CC0004%3A1%2CC0005%3A1%2CC0002%3A1&geolocation=CN%3BBJ&AwaitingReconsent=false; _biz_nA=7; _uetsid=453e0540536f11ee95f58376d4d2aec7; _uetvid=453eb7f0536f11ee8974ffcdc2ddaa63; _biz_pendingA=%5B%5D; _vwo_sn=0%3A6;',
          'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.81'}
def get_clarivate(url):
    # 创建数据表存储结果
    data = pd.DataFrame(columns=['INNOVATOR','REGION/COUNTRY', 'INDUSTRY'])
    
    for i in range(1, 5):
        page_url = url + str(i)
        # 解析页面
        html = requests.get(page_url, headers=headers).text
        soup = BeautifulSoup(html, 'html.parser')
        # 获取table
        table = soup.find('table', class_='table')
        tbody = table.find_all('tbody')
        # 获取全部tbody标签
        for body in tbody:
            tds = body.tr.find_all('td')
            value = [tds[0].text.strip(), tds[1].text.strip(), tds[2].text.strip()]
            # 将结果写入数据表
            data.loc[len(data.index)] = value
            # 打印结果
            print(value)
        time.sleep(3)
        
    #     # 将结果写入excel       
    data.to_excel('Clarivate 100.xlsx', index=False)

url = 'https://clarivate.com/top-100-innovators/the-top-100/?utm_medium=Organic%2FSearch&utm_source=www-google-com&wpv_view_count=204356&clv-region-country=0&clv-industries=0&clv-award-year=2023&wpv_post_search=&wpv_paged='
get_clarivate(url)
# Out:
# ['3M', 'United States', 'Chemicals and materials']
# ['AAC Technologies', 'China, Mainland', 'Electronics and computing equipment']
# ['ABB', 'Switzerland', 'Industrial systems']
# ['AGC', 'Japan', 'Chemicals and materials']
# ['Airbus', 'France', 'Aerospace and defense']
# ['Alphabet', 'United States', 'Software, media, fintech']
# ['Ant Group', 'China, Mainland', 'Software, media, fintech']
# ['Applied Materials', 'United States', 'Semiconductors']
# ['ASML', 'Netherlands', 'Semiconductors']
# ['AUO', 'Taiwan', 'Electronics and computing equipment']
# ['BASF', 'Germany', 'Chemicals and materials']
# ['BOE Technology', 'China, Mainland', 'Electronics and computing equipment']
# ['Boeing', 'United States', 'Aerospace and defense']
# ['Bosch', 'Germany', 'Industrial conglomerate']
# ['Brother Industries', 'Japan', 'Electronics and computing equipment']
# ['Canon', 'Japan', 'Electronics and computing equipment']
# ['CEA', 'France', 'Government and academic research']
# ...
